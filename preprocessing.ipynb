# %%
link="https://github.com/CAP-CoyunturasCriticas/BookMaps2011/raw/refs/heads/main/Elecciones%202011_Distrital.xlsx"

import pandas as pd

e2011p=pd.read_excel(link,dtype={'UBIGEO': object})
e20112=pd.read_excel(link,1,dtype={'UBIGEO': object})

# %%
e20112.columns
# Out:
# Index(['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'UBIGEO', 'FUERZA 2011',
#        'GANA PERU', 'VOTOS VALIDOS', 'VOTOS BLANCOS', 'VOTOS NULOS',
#        'VOTOS EMITIDOS', 'TOTAL ELECTORES', 'AUSENTISMO'],
#       dtype='object')

# %%
e2011p=e2011p.loc[:,['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'UBIGEO','GANA PERU','VOTOS VÁLIDOS']]
e20112=e20112.loc[:,['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'UBIGEO','GANA PERU','VOTOS VALIDOS']]

# %%
e2011p['Ollanta1']=e2011p['GANA PERU']/e2011p['VOTOS VÁLIDOS']
e20112['Ollanta2']=e20112['GANA PERU']/e20112['VOTOS VALIDOS']

# %%
e2011p=e2011p[~e2011p.UBIGEO.str.startswith('9')]
e20112=e20112[~e20112.UBIGEO.str.startswith('9')]

# %%
e2011p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1836 entries, 0 to 1835
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DEPARTAMENTO   1836 non-null   object
#  1   PROVINCIA      1836 non-null   object
#  2   DISTRITO       1836 non-null   object
#  3   UBIGEO         1836 non-null   object
#  4   GANA PERU      1836 non-null   float64
#  5   VOTOS VÁLIDOS  1836 non-null   float64
#  6   Ollanta1       1836 non-null   float64
# dtypes: float64(3), object(4)
# memory usage: 114.8+ KB

# %%
e20112.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1836 entries, 0 to 1835
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DEPARTAMENTO   1836 non-null   object
#  1   PROVINCIA      1836 non-null   object
#  2   DISTRITO       1836 non-null   object
#  3   UBIGEO         1836 non-null   object
#  4   GANA PERU      1836 non-null   float64
#  5   VOTOS VALIDOS  1836 non-null   float64
#  6   Ollanta2       1836 non-null   float64
# dtypes: float64(3), object(4)
# memory usage: 114.8+ KB

# %%
e2011=e2011p.merge(e20112,on=['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'UBIGEO'])
e2011=e2011.loc[:,['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'UBIGEO','Ollanta1','Ollanta2']]


from unidecode import unidecode

e2011['DISTRITO']=e2011.DISTRITO.apply(unidecode)
e2011['PROVINCIA']=e2011.PROVINCIA.apply(unidecode)

# %%
link2='https://github.com/CAP-CoyunturasCriticas/BookMaps2011/raw/refs/heads/main/inei.xlsx'
inei=pd.read_excel(link2,dtype={'Ubigeo': str})
inei
# Out:
#       Ubigeo                                 Nombre de Distrito  redpub_porc  \
# 0     010101  Dpto. Amazonas   Prov. Chachapoyas   Dist. Cha...    70.989011
# 1     010102  Dpto. Amazonas   Prov. Chachapoyas   Dist. Asu...     0.000000
# 2     010103  Dpto. Amazonas   Prov. Chachapoyas   Dist. Balsas     2.332362
# 3     010104   Dpto. Amazonas   Prov. Chachapoyas   Dist. Cheto     3.614458
# 4     010105  Dpto. Amazonas   Prov. Chachapoyas   Dist. Chi...    10.526316
# ...      ...                                                ...          ...
# 1828  250204        Dpto. Ucayali   Prov. Atalaya   Dist. Yurua     0.000000
# 1829  250301  Dpto. Ucayali   Prov. Padre Abad   Dist. Padre...    12.657823
# 1830  250302   Dpto. Ucayali   Prov. Padre Abad   Dist. Irazola    11.468628
# 1831  250303  Dpto. Ucayali   Prov. Padre Abad   Dist. Curimana    10.000000
# 1832  250401          Dpto. Ucayali   Prov. Purus   Dist. Purus     0.000000
#
#        dni_porc  elec_porc  salud_porc   edu_porc  trabajo_porc
# 0     97.235825  90.894819   45.356949  47.833363     35.007644
# 1     96.517413  47.191011   64.359862  24.087591      9.589041
# 2     90.306122  39.650146   50.249822  18.876755      6.638116
# 3     97.727273  78.313253   45.017182  17.636364      3.361345
# 4     93.644860  44.939271   52.526439   9.336609      4.594595
# ...         ...        ...         ...        ...           ...
# 1828  70.950469  23.529412   34.273452  18.846695     19.339623
# 1829  94.438503  55.154227   36.250146  39.429799     10.199862
# 1830  92.936632  33.187773   31.343205  32.271031      5.488851
# 1831  92.589312  22.517986   37.043162  33.964669      4.055767
# 1832  95.954357  32.336957   74.906567  32.577566     26.495726
#
# [1833 rows x 8 columns]

# %%
inei.rename(columns={'Ubigeo':'UBIGEO'},inplace=True)

# %%
inei[~inei['Nombre de Distrito'].str.contains('Dist. ')]
# Out:
# Empty DataFrame
# Columns: [UBIGEO, Nombre de Distrito, redpub_porc, dni_porc, elec_porc, salud_porc, edu_porc, trabajo_porc, PROVINCIA, DISTRITO]
# Index: []

# %%
inei[~inei['Nombre de Distrito'].str.contains('Prov. ')]
# Out:
# Empty DataFrame
# Columns: [UBIGEO, Nombre de Distrito, redpub_porc, dni_porc, elec_porc, salud_porc, edu_porc, trabajo_porc, PROVINCIA, DISTRITO]
# Index: []

# %%
inei[['PROVINCIA','DISTRITO']]=inei['Nombre de Distrito'].str.split('Prov. |Dist. ',expand=True).iloc[:,[1,2]]
inei[['PROVINCIA','DISTRITO']]=inei[['PROVINCIA','DISTRITO']].apply(lambda x:x.str.strip().str.upper())
inei
# Out:
#       UBIGEO                                 Nombre de Distrito  redpub_porc  \
# 0     010101  Dpto. Amazonas   Prov. Chachapoyas   Dist. Cha...    70.989011
# 1     010102  Dpto. Amazonas   Prov. Chachapoyas   Dist. Asu...     0.000000
# 2     010103  Dpto. Amazonas   Prov. Chachapoyas   Dist. Balsas     2.332362
# 3     010104   Dpto. Amazonas   Prov. Chachapoyas   Dist. Cheto     3.614458
# 4     010105  Dpto. Amazonas   Prov. Chachapoyas   Dist. Chi...    10.526316
# ...      ...                                                ...          ...
# 1828  250204        Dpto. Ucayali   Prov. Atalaya   Dist. Yurua     0.000000
# 1829  250301  Dpto. Ucayali   Prov. Padre Abad   Dist. Padre...    12.657823
# 1830  250302   Dpto. Ucayali   Prov. Padre Abad   Dist. Irazola    11.468628
# 1831  250303  Dpto. Ucayali   Prov. Padre Abad   Dist. Curimana    10.000000
# 1832  250401          Dpto. Ucayali   Prov. Purus   Dist. Purus     0.000000
#
#        dni_porc  elec_porc  salud_porc   edu_porc  trabajo_porc    PROVINCIA  \
# 0     97.235825  90.894819   45.356949  47.833363     35.007644  CHACHAPOYAS
# 1     96.517413  47.191011   64.359862  24.087591      9.589041  CHACHAPOYAS
# 2     90.306122  39.650146   50.249822  18.876755      6.638116  CHACHAPOYAS
# 3     97.727273  78.313253   45.017182  17.636364      3.361345  CHACHAPOYAS
# 4     93.644860  44.939271   52.526439   9.336609      4.594595  CHACHAPOYAS
# ...         ...        ...         ...        ...           ...          ...
# 1828  70.950469  23.529412   34.273452  18.846695     19.339623      ATALAYA
# 1829  94.438503  55.154227   36.250146  39.429799     10.199862   PADRE ABAD
# 1830  92.936632  33.187773   31.343205  32.271031      5.488851   PADRE ABAD
# 1831  92.589312  22.517986   37.043162  33.964669      4.055767   PADRE ABAD
# 1832  95.954357  32.336957   74.906567  32.577566     26.495726        PURUS
#
#          DISTRITO
# 0     CHACHAPOYAS
# 1        ASUNCIÓN
# 2          BALSAS
# 3           CHETO
# 4       CHILIQUIN
# ...           ...
# 1828        YURUA
# 1829   PADRE ABAD
# 1830      IRAZOLA
# 1831     CURIMANA
# 1832        PURUS
#
# [1833 rows x 10 columns]

# %%
inei['DISTRITO']=inei.DISTRITO.apply(unidecode)
inei['PROVINCIA']=inei.PROVINCIA.apply(unidecode)

# %%
e2011.merge(inei,on=['PROVINCIA','DISTRITO'])
# Out:
#      DEPARTAMENTO    PROVINCIA     DISTRITO UBIGEO_x  Ollanta1  Ollanta2  \
# 0        AMAZONAS  CHACHAPOYAS  CHACHAPOYAS   010101  0.266505  0.575276
# 1        AMAZONAS  CHACHAPOYAS     ASUNCION   010102  0.292857  0.713376
# 2        AMAZONAS  CHACHAPOYAS       BALSAS   010103  0.137803  0.341772
# 3        AMAZONAS  CHACHAPOYAS        CHETO   010104  0.462396  0.638462
# 4        AMAZONAS  CHACHAPOYAS    CHILIQUIN   010105  0.263666  0.373762
# ...           ...          ...          ...      ...       ...       ...
# 1787      UCAYALI   PADRE ABAD     CURIMANA   250203  0.623040  0.690476
# 1788      UCAYALI      ATALAYA     TAHUANIA   250302  0.444015  0.617647
# 1789      UCAYALI      ATALAYA        YURUA   250303  0.137584  0.137255
# 1790      UCAYALI      ATALAYA      SEPAHUA   250304  0.328624  0.384081
# 1791      UCAYALI        PURUS        PURUS   250401  0.225691  0.284345
#
#      UBIGEO_y                                 Nombre de Distrito  redpub_porc  \
# 0      010101  Dpto. Amazonas   Prov. Chachapoyas   Dist. Cha...    70.989011
# 1      010102  Dpto. Amazonas   Prov. Chachapoyas   Dist. Asu...     0.000000
# 2      010103  Dpto. Amazonas   Prov. Chachapoyas   Dist. Balsas     2.332362
# 3      010104   Dpto. Amazonas   Prov. Chachapoyas   Dist. Cheto     3.614458
# 4      010105  Dpto. Amazonas   Prov. Chachapoyas   Dist. Chi...    10.526316
# ...       ...                                                ...          ...
# 1787   250303  Dpto. Ucayali   Prov. Padre Abad   Dist. Curimana    10.000000
# 1788   250203     Dpto. Ucayali   Prov. Atalaya   Dist. Tahuania     9.032671
# 1789   250204        Dpto. Ucayali   Prov. Atalaya   Dist. Yurua     0.000000
# 1790   250202      Dpto. Ucayali   Prov. Atalaya   Dist. Sepahua    25.508721
# 1791   250401          Dpto. Ucayali   Prov. Purus   Dist. Purus     0.000000
#
#        dni_porc  elec_porc  salud_porc   edu_porc  trabajo_porc
# 0     97.235825  90.894819   45.356949  47.833363     35.007644
# 1     96.517413  47.191011   64.359862  24.087591      9.589041
# 2     90.306122  39.650146   50.249822  18.876755      6.638116
# 3     97.727273  78.313253   45.017182  17.636364      3.361345
# 4     93.644860  44.939271   52.526439   9.336609      4.594595
# ...         ...        ...         ...        ...           ...
# 1787  92.589312  22.517986   37.043162  33.964669      4.055767
# 1788  79.424978  41.575913   46.224602  21.312741      5.864726
# 1789  70.950469  23.529412   34.273452  18.846695     19.339623
# 1790  91.419558  32.340116   56.521739  32.028411     15.572391
# 1791  95.954357  32.336957   74.906567  32.577566     26.495726
#
# [1792 rows x 14 columns]

# %%
e2011['key']=[p+'_'+d for p,d in zip(e2011.PROVINCIA,e2011.DISTRITO)]
inei['key']=[p+'_'+d for p,d in zip(inei.PROVINCIA,inei.DISTRITO)]

# %%
eleonly=set(e2011.key)-set(inei.key)
ineionly=set(inei.key)-set(e2011.key)

# %%
from thefuzz import process

[(anInei,process.extractOne(anInei, eleonly)) for anInei in ineionly]
# Out:
# [('SAN MARTIN_PAPAPLAYA', ('SAN MARTIN_PAPA-PLAYA', 98)),
#  ('CONSTITUCIONAL DEL CALLAO_CALLAO', ('CALLAO_CALLAO', 90)),
#  ('AMBO_TOMAY KICHWA', ('AMBO_TOMAY-KICHWA', 100)),
#  ('DANIEL ALCIDES CARRION_GOYLLARISQUIZGA',
#   ('DANIEL CARRION_GOYLLARISQUIZGA', 95)),
#  ('DANIEL ALCIDES CARRION_PAUCAR', ('DANIEL CARRION_PAUCAR', 95)),
#  ('LIMA_MAGDALENA VIEJA', ('LIMA_PUEBLO LIBRE', 49)),
#  ('VICTOR FAFARDO_CANARIA', ('VICTOR FAJARDO_CANARIA', 95)),
#  ('ANTONIO RAYMONDI_CHACCHO', ('ANTONIO RAIMONDI_CHACCHO', 96)),
#  ('LEONCIO PRADO_DANIEL ALOMIAS ROBLES',
#   ('LEONCIO PRADO_DANIEL ALOMIA ROBLES', 99)),
#  ('VICTOR FAJARDO_HUAYA', ('VICTOR FAJARDO_HUALLA', 93)),
#  ('AREQUIPA_SANTA RITA DE SIGUAS', ('AREQUIPA_SANTA RITA DE SIHUAS', 97)),
#  ('REQUENA_SAQUENA', ('REQUENA_SAPUENA', 93)),
#  ('SECHURA_RINCONADA LLICUAR', ('SECHURA_RINCONADA-LLICUAR', 100)),
#  ('DANIEL ALCIDES CARRION_YANAHUANCA', ('DANIEL CARRION_YANAHUANCA', 95)),
#  ('CHINCHEROS_ANCO_HUALLO', ('CHINCHEROS_ANCO-HUALLO', 95)),
#  ('CONSTITUCIONAL DEL CALLAO_VENTANILLA', ('CALLAO_VENTANILLA', 90)),
#  ('DANIEL ALCIDES CARRION_TAPUC', ('DANIEL CARRION_TAPUC', 95)),
#  ('HUAROCHIRI_SAN PEDRO DE CASTA',
#   ('HUAROCHIRI_CUENCA (SAN JOSE DE LOS CHORRILLOS)', 86)),
#  ('CONTUMAZA_SANTA CRUZ DE TOLEDO', ('CONTUMAZA_SANTA CRUZ DE TOLED', 98)),
#  ('ATALAYA_RAYMONDI', ('ATALAYA_RAIMONDI', 94)),
#  ('ANGARAES_HUAYLLAY GRANDE', ('ANGARAES_HUALLAY-GRANDE', 98)),
#  ('ANTONIO RAYMONDI_CHINGAS', ('ANTONIO RAIMONDI_CHINGAS', 96)),
#  ('DANIEL ALCIDES CARRION_CHACAYAN', ('DANIEL CARRION_CHACAYAN', 95)),
#  ('ANTONIO RAYMONDI_ACZO', ('ANTONIO RAIMONDI_ACZO', 95)),
#  ('CONSTITUCIONAL DEL CALLAO_LA PUNTA', ('CALLAO_LA PUNTA', 90)),
#  ('ANTONIO RAYMONDI_LLAMELLIN', ('ANTONIO RAIMONDI_LLAMELLIN', 96)),
#  ('SATIPO_TEMPORAL POR LIMITES', ('ANTONIO RAIMONDI_MIRGAS', 44)),
#  ('CONSTITUCIONAL DEL CALLAO_BELLAVISTA', ('CALLAO_BELLAVISTA', 90)),
#  ('CONSTITUCIONAL DEL CALLAO_LA PERLA', ('CALLAO_LA PERLA', 90)),
#  ('DANIEL ALCIDES CARRION_VILCABAMBA', ('DANIEL CARRION_VILCABAMBA', 95)),
#  ('ANTONIO RAYMONDI_MIRGAS', ('ANTONIO RAIMONDI_MIRGAS', 96)),
#  ('CONSTITUCIONAL DEL CALLAO_CARMEN DE LA LEGUA REYNOSO',
#   ('CALLAO_CARMEN DE LA LEGUA-REYNOSO', 90)),
#  ('RODRIGUEZ DE MENDOZA_MILPUC', ('RODRIGUEZ DE MENDOZA_MILPUCC', 98)),
#  ('DANIEL ALCIDES CARRION_SANTA ANA DE TUSI',
#   ('DANIEL CARRION_SANTA ANA DE TUSI', 95)),
#  ('GRAN CHIMU_COMPIN', ('GRAN CHIMU_MARMOT', 71)),
#  ('DANIEL ALCIDES CARRION_SAN PEDRO DE PILLAO',
#   ('DANIEL CARRION_SAN PEDRO DE PILLAO', 95)),
#  ('CHACHAPOYAS_LEIMEBAMBA', ('CHACHAPOYAS_LEYMEBAMBA', 95)),
#  ('PUIRA_LA UNION', ('PIURA_LA UNION', 93)),
#  ('ANTONIO RAYMONDI_SAN JUAN DE RONTOY',
#   ('ANTONIO RAIMONDI_SAN JUAN DE RONTOY', 97)),
#  ('TARATA_ESTIQUE-PAMPA', ('TARATA_ESTIQUE PAMPA', 100)),
#  ('HUAROCHIRI_CUENCA', ('HUAROCHIRI_CUENCA (SAN JOSE DE LOS CHORRILLOS)', 90))]

# %%
inei.key[inei['key'].str.contains("CALLAO|RAYMONDI")]
# Out:
# 100                            ANTONIO RAYMONDI_LLAMELLIN
# 101                                 ANTONIO RAYMONDI_ACZO
# 102                              ANTONIO RAYMONDI_CHACCHO
# 103                              ANTONIO RAYMONDI_CHINGAS
# 104                               ANTONIO RAYMONDI_MIRGAS
# 105                   ANTONIO RAYMONDI_SAN JUAN DE RONTOY
# 110                            BOLOGNESI_ANTONIO RAYMONDI
# 675                      CONSTITUCIONAL DEL CALLAO_CALLAO
# 676                  CONSTITUCIONAL DEL CALLAO_BELLAVISTA
# 677     CONSTITUCIONAL DEL CALLAO_CARMEN DE LA LEGUA R...
# 678                    CONSTITUCIONAL DEL CALLAO_LA PERLA
# 679                    CONSTITUCIONAL DEL CALLAO_LA PUNTA
# 680                  CONSTITUCIONAL DEL CALLAO_VENTANILLA
# 1825                                     ATALAYA_RAYMONDI
# Name: key, dtype: object

# %%
inei['key']=inei['key'].str.replace("CONSTITUCIONAL DEL CALLAO","CALLAO")
inei['key']=inei['key'].str.replace("RAYMONDI","RAIMONDI")

# %%
e2011.key[e2011['key'].str.contains("DANIEL CARRION")]
# Out:
# 1509             DANIEL CARRION_YANAHUANCA
# 1510               DANIEL CARRION_CHACAYAN
# 1511        DANIEL CARRION_GOYLLARISQUIZGA
# 1512                 DANIEL CARRION_PAUCAR
# 1513    DANIEL CARRION_SAN PEDRO DE PILLAO
# 1514      DANIEL CARRION_SANTA ANA DE TUSI
# 1515                  DANIEL CARRION_TAPUC
# 1516             DANIEL CARRION_VILCABAMBA
# Name: key, dtype: object

# %%
e2011['key']=e2011['key'].str.replace("DANIEL CARRION","DANIEL ALCIDES CARRION")

# %%
eleonly=set(e2011.key)-set(inei.key)
ineionly=set(inei.key)-set(e2011.key)
[(anInei,process.extractOne(anInei, eleonly)) for anInei in ineionly]
# Out:
# [('SAN MARTIN_PAPAPLAYA', ('SAN MARTIN_PAPA-PLAYA', 98)),
#  ('CALLAO_CARMEN DE LA LEGUA REYNOSO',
#   ('CALLAO_CARMEN DE LA LEGUA-REYNOSO', 100)),
#  ('AMBO_TOMAY KICHWA', ('AMBO_TOMAY-KICHWA', 100)),
#  ('LIMA_MAGDALENA VIEJA', ('LIMA_PUEBLO LIBRE', 49)),
#  ('VICTOR FAFARDO_CANARIA', ('VICTOR FAJARDO_CANARIA', 95)),
#  ('LEONCIO PRADO_DANIEL ALOMIAS ROBLES',
#   ('LEONCIO PRADO_DANIEL ALOMIA ROBLES', 99)),
#  ('VICTOR FAJARDO_HUAYA', ('VICTOR FAJARDO_HUALLA', 93)),
#  ('AREQUIPA_SANTA RITA DE SIGUAS', ('AREQUIPA_SANTA RITA DE SIHUAS', 97)),
#  ('REQUENA_SAQUENA', ('REQUENA_SAPUENA', 93)),
#  ('SECHURA_RINCONADA LLICUAR', ('SECHURA_RINCONADA-LLICUAR', 100)),
#  ('CHINCHEROS_ANCO_HUALLO', ('CHINCHEROS_ANCO-HUALLO', 95)),
#  ('HUAROCHIRI_SAN PEDRO DE CASTA',
#   ('HUAROCHIRI_CUENCA (SAN JOSE DE LOS CHORRILLOS)', 86)),
#  ('CONTUMAZA_SANTA CRUZ DE TOLEDO', ('CONTUMAZA_SANTA CRUZ DE TOLED', 98)),
#  ('ANGARAES_HUAYLLAY GRANDE', ('ANGARAES_HUALLAY-GRANDE', 98)),
#  ('BOLOGNESI_ANTONIO RAIMONDI', ('BOLOGNESI_ANTONIO RAYMONDI', 96)),
#  ('SATIPO_TEMPORAL POR LIMITES', ('AREQUIPA_SANTA RITA DE SIHUAS', 43)),
#  ('RODRIGUEZ DE MENDOZA_MILPUC', ('RODRIGUEZ DE MENDOZA_MILPUCC', 98)),
#  ('GRAN CHIMU_COMPIN', ('GRAN CHIMU_MARMOT', 71)),
#  ('CHACHAPOYAS_LEIMEBAMBA', ('CHACHAPOYAS_LEYMEBAMBA', 95)),
#  ('PUIRA_LA UNION', ('PIURA_LA UNION', 93)),
#  ('TARATA_ESTIQUE-PAMPA', ('TARATA_ESTIQUE PAMPA', 100)),
#  ('HUAROCHIRI_CUENCA', ('HUAROCHIRI_CUENCA (SAN JOSE DE LOS CHORRILLOS)', 90))]

# %%
[(anInei,process.extractOne(anInei, eleonly)) for anInei in ineionly if process.extractOne(anInei, eleonly)[1]>=90]
# Out:
# [('SAN MARTIN_PAPAPLAYA', ('SAN MARTIN_PAPA-PLAYA', 98)),
#  ('CALLAO_CARMEN DE LA LEGUA REYNOSO',
#   ('CALLAO_CARMEN DE LA LEGUA-REYNOSO', 100)),
#  ('AMBO_TOMAY KICHWA', ('AMBO_TOMAY-KICHWA', 100)),
#  ('VICTOR FAFARDO_CANARIA', ('VICTOR FAJARDO_CANARIA', 95)),
#  ('LEONCIO PRADO_DANIEL ALOMIAS ROBLES',
#   ('LEONCIO PRADO_DANIEL ALOMIA ROBLES', 99)),
#  ('VICTOR FAJARDO_HUAYA', ('VICTOR FAJARDO_HUALLA', 93)),
#  ('AREQUIPA_SANTA RITA DE SIGUAS', ('AREQUIPA_SANTA RITA DE SIHUAS', 97)),
#  ('REQUENA_SAQUENA', ('REQUENA_SAPUENA', 93)),
#  ('SECHURA_RINCONADA LLICUAR', ('SECHURA_RINCONADA-LLICUAR', 100)),
#  ('CHINCHEROS_ANCO_HUALLO', ('CHINCHEROS_ANCO-HUALLO', 95)),
#  ('CONTUMAZA_SANTA CRUZ DE TOLEDO', ('CONTUMAZA_SANTA CRUZ DE TOLED', 98)),
#  ('ANGARAES_HUAYLLAY GRANDE', ('ANGARAES_HUALLAY-GRANDE', 98)),
#  ('BOLOGNESI_ANTONIO RAIMONDI', ('BOLOGNESI_ANTONIO RAYMONDI', 96)),
#  ('RODRIGUEZ DE MENDOZA_MILPUC', ('RODRIGUEZ DE MENDOZA_MILPUCC', 98)),
#  ('CHACHAPOYAS_LEIMEBAMBA', ('CHACHAPOYAS_LEYMEBAMBA', 95)),
#  ('PUIRA_LA UNION', ('PIURA_LA UNION', 93)),
#  ('TARATA_ESTIQUE-PAMPA', ('TARATA_ESTIQUE PAMPA', 100)),
#  ('HUAROCHIRI_CUENCA', ('HUAROCHIRI_CUENCA (SAN JOSE DE LOS CHORRILLOS)', 90))]

# %%
dictOfChanges_1={anInei:process.extractOne(anInei, eleonly)[0] for anInei in ineionly if process.extractOne(anInei, eleonly)[1]>=90}
dictOfChanges_1
# Out:
# {'SAN MARTIN_PAPAPLAYA': 'SAN MARTIN_PAPA-PLAYA',
#  'CALLAO_CARMEN DE LA LEGUA REYNOSO': 'CALLAO_CARMEN DE LA LEGUA-REYNOSO',
#  'AMBO_TOMAY KICHWA': 'AMBO_TOMAY-KICHWA',
#  'VICTOR FAFARDO_CANARIA': 'VICTOR FAJARDO_CANARIA',
#  'LEONCIO PRADO_DANIEL ALOMIAS ROBLES': 'LEONCIO PRADO_DANIEL ALOMIA ROBLES',
#  'VICTOR FAJARDO_HUAYA': 'VICTOR FAJARDO_HUALLA',
#  'AREQUIPA_SANTA RITA DE SIGUAS': 'AREQUIPA_SANTA RITA DE SIHUAS',
#  'REQUENA_SAQUENA': 'REQUENA_SAPUENA',
#  'SECHURA_RINCONADA LLICUAR': 'SECHURA_RINCONADA-LLICUAR',
#  'CHINCHEROS_ANCO_HUALLO': 'CHINCHEROS_ANCO-HUALLO',
#  'CONTUMAZA_SANTA CRUZ DE TOLEDO': 'CONTUMAZA_SANTA CRUZ DE TOLED',
#  'ANGARAES_HUAYLLAY GRANDE': 'ANGARAES_HUALLAY-GRANDE',
#  'BOLOGNESI_ANTONIO RAIMONDI': 'BOLOGNESI_ANTONIO RAYMONDI',
#  'RODRIGUEZ DE MENDOZA_MILPUC': 'RODRIGUEZ DE MENDOZA_MILPUCC',
#  'CHACHAPOYAS_LEIMEBAMBA': 'CHACHAPOYAS_LEYMEBAMBA',
#  'PUIRA_LA UNION': 'PIURA_LA UNION',
#  'TARATA_ESTIQUE-PAMPA': 'TARATA_ESTIQUE PAMPA',
#  'HUAROCHIRI_CUENCA': 'HUAROCHIRI_CUENCA (SAN JOSE DE LOS CHORRILLOS)'}

# %%
inei.replace({'key':dictOfChanges_1}, inplace=True)

eleonly=set(e2011.key)-set(inei.key)
ineionly=set(inei.key)-set(e2011.key)
[(anInei,process.extractOne(anInei, eleonly)) for anInei in ineionly]
# Out:
# [('SATIPO_TEMPORAL POR LIMITES', ('LIMA_PUEBLO LIBRE', 42)),
#  ('GRAN CHIMU_COMPIN', ('GRAN CHIMU_MARMOT', 71)),
#  ('LIMA_MAGDALENA VIEJA', ('LIMA_PUEBLO LIBRE', 49)),
#  ('HUAROCHIRI_SAN PEDRO DE CASTA', ('HUAROCHIRI_CASTA', 73))]

# %%
e2011.key[e2011['key'].str.contains("SATIPO")]
# Out:
# 1099           SATIPO_SATIPO
# 1100        SATIPO_COVIRIALI
# 1101          SATIPO_LLAYLLA
# 1102         SATIPO_MAZAMARI
# 1103    SATIPO_PAMPA HERMOSA
# 1104           SATIPO_PANGOA
# 1105        SATIPO_RIO NEGRO
# 1106        SATIPO_RIO TAMBO
# Name: key, dtype: object

# %%
inei.key[inei['key'].str.contains("SATIPO")]
# Out:
# 1089                  SATIPO_SATIPO
# 1090               SATIPO_COVIRIALI
# 1091                 SATIPO_LLAYLLA
# 1092                SATIPO_MAZAMARI
# 1093           SATIPO_PAMPA HERMOSA
# 1094                  SATIPO_PANGOA
# 1095               SATIPO_RIO NEGRO
# 1096               SATIPO_RIO TAMBO
# 1097    SATIPO_TEMPORAL POR LIMITES
# Name: key, dtype: object

# %%
e2011.shape,inei.shape
# Out:
# ((1836, 7), (1833, 11))

# %%
dictOfChanges_2={anInei:process.extractOne(anInei, eleonly)[0] for anInei in ineionly if process.extractOne(anInei, eleonly)[1]>42}
dictOfChanges_2
# Out:
# {'GRAN CHIMU_COMPIN': 'GRAN CHIMU_MARMOT',
#  'LIMA_MAGDALENA VIEJA': 'LIMA_PUEBLO LIBRE',
#  'HUAROCHIRI_SAN PEDRO DE CASTA': 'HUAROCHIRI_CASTA'}

# %%
inei.replace({'key':dictOfChanges_2}, inplace=True)

eleonly=set(e2011.key)-set(inei.key)
ineionly=set(inei.key)-set(e2011.key)
[(anInei,process.extractOne(anInei, eleonly)) for anInei in ineionly]
# Out:
# [('SATIPO_TEMPORAL POR LIMITES', ('CHURCAMPA_COSME', 36))]

# %%
eleonly
# Out:
# {'BAGUA_BAGUA',
#  'CHURCAMPA_COSME',
#  'HUAMANGA_CARMEN ALTO',
#  'OXAPAMPA_CONSTITUCION'}

# %%
ineionly
# Out:
# {'SATIPO_TEMPORAL POR LIMITES'}

# %%
inei[inei.PROVINCIA.str.contains("HUAMANGA")]
# Out:
#      UBIGEO                                 Nombre de Distrito  redpub_porc  \
# 438  050101   Dpto. Ayacucho   Prov. Huamanga   Dist. Ayacucho    76.090659
# 439  050102     Dpto. Ayacucho   Prov. Huamanga   Dist. Acocro    12.162741
# 440  050103  Dpto. Ayacucho   Prov. Huamanga   Dist. Acos V...    28.690575
# 441  050105     Dpto. Ayacucho   Prov. Huamanga   Dist. Chiara    11.055276
# 442  050106      Dpto. Ayacucho   Prov. Huamanga   Dist. Ocros    16.953825
# 443  050107  Dpto. Ayacucho   Prov. Huamanga   Dist. Pacaycasa    52.781955
# 444  050108     Dpto. Ayacucho   Prov. Huamanga   Dist. Quinua    21.411192
# 445  050109  Dpto. Ayacucho   Prov. Huamanga   Dist. San Jo...     1.994681
# 446  050110  Dpto. Ayacucho   Prov. Huamanga   Dist. San Ju...    77.637181
# 447  050111  Dpto. Ayacucho   Prov. Huamanga   Dist. Santia...    25.303293
# 448  050112      Dpto. Ayacucho   Prov. Huamanga   Dist. Socos     5.933682
# 449  050113   Dpto. Ayacucho   Prov. Huamanga   Dist. Tambillo     6.896552
# 450  050114    Dpto. Ayacucho   Prov. Huamanga   Dist. Vinchos    13.358396
# 451  050115  Dpto. Ayacucho   Prov. Huamanga   Dist. Jesus ...    67.812669
#
#       dni_porc  elec_porc  salud_porc   edu_porc  trabajo_porc PROVINCIA  \
# 438  97.406727  84.265688   39.025115  47.814586     32.450676  HUAMANGA
# 439  98.680628  27.837259   73.193343  20.407668      2.086614  HUAMANGA
# 440  98.346486  26.772310   76.509804  21.646662      2.904239  HUAMANGA
# 441  98.514574  23.785595   67.179325  25.794264      2.184273  HUAMANGA
# 442  95.741805  18.814611   67.764915  26.082827      4.721030  HUAMANGA
# 443  97.991212  63.759398   57.952146  32.932783      2.818627  HUAMANGA
# 444  98.587340  55.839416   56.778414  27.975164     24.761905  HUAMANGA
# 445  98.421414  54.787234   71.621622  22.833260      5.967977  HUAMANGA
# 446  98.326304  85.371334   44.158411  45.120637     25.667010  HUAMANGA
# 447  98.496241  57.192374   60.395365  26.695527      3.290676  HUAMANGA
# 448  99.246096  66.899360   77.603940  20.018680      2.838893  HUAMANGA
# 449  98.989143  49.137931   80.682715  22.059448      2.784603  HUAMANGA
# 450  98.748894  43.383459   79.514791  14.104870      2.831010  HUAMANGA
# 451  98.141583  89.740119   42.892396  46.194081     26.206765  HUAMANGA
#
#                 DISTRITO                           key
# 438             AYACUCHO             HUAMANGA_AYACUCHO
# 439               ACOCRO               HUAMANGA_ACOCRO
# 440         ACOS VINCHOS         HUAMANGA_ACOS VINCHOS
# 441               CHIARA               HUAMANGA_CHIARA
# 442                OCROS                HUAMANGA_OCROS
# 443            PACAYCASA            HUAMANGA_PACAYCASA
# 444               QUINUA               HUAMANGA_QUINUA
# 445  SAN JOSE DE TICLLAS  HUAMANGA_SAN JOSE DE TICLLAS
# 446    SAN JUAN BAUTISTA    HUAMANGA_SAN JUAN BAUTISTA
# 447   SANTIAGO DE PISCHA   HUAMANGA_SANTIAGO DE PISCHA
# 448                SOCOS                HUAMANGA_SOCOS
# 449             TAMBILLO             HUAMANGA_TAMBILLO
# 450              VINCHOS              HUAMANGA_VINCHOS
# 451       JESUS NAZARENO       HUAMANGA_JESUS NAZARENO

# %%
e2011[e2011.PROVINCIA.str.contains("HUAMANGA")]
# Out:
#     DEPARTAMENTO PROVINCIA             DISTRITO  UBIGEO  Ollanta1  Ollanta2  \
# 439     AYACUCHO  HUAMANGA             AYACUCHO  050101  0.501118  0.699420
# 440     AYACUCHO  HUAMANGA         ACOS VINCHOS  050102  0.623684  0.700680
# 441     AYACUCHO  HUAMANGA          CARMEN ALTO  050103  0.621305  0.749028
# 442     AYACUCHO  HUAMANGA               CHIARA  050104  0.743797  0.815353
# 443     AYACUCHO  HUAMANGA               QUINUA  050105  0.578834  0.689108
# 444     AYACUCHO  HUAMANGA  SAN JOSE DE TICLLAS  050106  0.552497  0.665818
# 445     AYACUCHO  HUAMANGA    SAN JUAN BAUTISTA  050107  0.595001  0.755242
# 446     AYACUCHO  HUAMANGA   SANTIAGO DE PISCHA  050108  0.627409  0.678756
# 447     AYACUCHO  HUAMANGA              VINCHOS  050109  0.715224  0.830490
# 448     AYACUCHO  HUAMANGA             TAMBILLO  050110  0.547016  0.658884
# 449     AYACUCHO  HUAMANGA               ACOCRO  050111  0.717098  0.813619
# 450     AYACUCHO  HUAMANGA                SOCOS  050112  0.573618  0.707258
# 451     AYACUCHO  HUAMANGA                OCROS  050113  0.649032  0.782625
# 452     AYACUCHO  HUAMANGA            PACAYCASA  050114  0.424242  0.508392
# 453     AYACUCHO  HUAMANGA       JESUS NAZARENO  050115  0.520795  0.693272
#
#                               key
# 439             HUAMANGA_AYACUCHO
# 440         HUAMANGA_ACOS VINCHOS
# 441          HUAMANGA_CARMEN ALTO
# 442               HUAMANGA_CHIARA
# 443               HUAMANGA_QUINUA
# 444  HUAMANGA_SAN JOSE DE TICLLAS
# 445    HUAMANGA_SAN JUAN BAUTISTA
# 446   HUAMANGA_SANTIAGO DE PISCHA
# 447              HUAMANGA_VINCHOS
# 448             HUAMANGA_TAMBILLO
# 449               HUAMANGA_ACOCRO
# 450                HUAMANGA_SOCOS
# 451                HUAMANGA_OCROS
# 452            HUAMANGA_PACAYCASA
# 453       HUAMANGA_JESUS NAZARENO

# %%
data2011=e2011.merge(inei,on='key')
data2011.columns
# Out:
# Index(['DEPARTAMENTO', 'PROVINCIA_x', 'DISTRITO_x', 'UBIGEO_x', 'Ollanta1',
#        'Ollanta2', 'key', 'UBIGEO_y', 'Nombre de Distrito', 'redpub_porc',
#        'dni_porc', 'elec_porc', 'salud_porc', 'edu_porc', 'trabajo_porc',
#        'PROVINCIA_y', 'DISTRITO_y'],
#       dtype='object')

# %%
data2011.drop(columns=['UBIGEO_x','UBIGEO_y', 'Nombre de Distrito','PROVINCIA_y', 'DISTRITO_y','elec_porc'],inplace=True)

# %%
data2011.rename(columns={'PROVINCIA_x':'PROVINCIA','DISTRITO_x':'DISTRITO'},inplace=True)
data2011
# Out:
#      DEPARTAMENTO    PROVINCIA     DISTRITO  Ollanta1  Ollanta2  \
# 0        AMAZONAS  CHACHAPOYAS  CHACHAPOYAS  0.266505  0.575276
# 1        AMAZONAS  CHACHAPOYAS     ASUNCION  0.292857  0.713376
# 2        AMAZONAS  CHACHAPOYAS       BALSAS  0.137803  0.341772
# 3        AMAZONAS  CHACHAPOYAS        CHETO  0.462396  0.638462
# 4        AMAZONAS  CHACHAPOYAS    CHILIQUIN  0.263666  0.373762
# ...           ...          ...          ...       ...       ...
# 1827      UCAYALI      ATALAYA     RAIMONDI  0.271639  0.441510
# 1828      UCAYALI      ATALAYA     TAHUANIA  0.444015  0.617647
# 1829      UCAYALI      ATALAYA        YURUA  0.137584  0.137255
# 1830      UCAYALI      ATALAYA      SEPAHUA  0.328624  0.384081
# 1831      UCAYALI        PURUS        PURUS  0.225691  0.284345
#
#                           key  redpub_porc   dni_porc  salud_porc   edu_porc  \
# 0     CHACHAPOYAS_CHACHAPOYAS    70.989011  97.235825   45.356949  47.833363
# 1        CHACHAPOYAS_ASUNCION     0.000000  96.517413   64.359862  24.087591
# 2          CHACHAPOYAS_BALSAS     2.332362  90.306122   50.249822  18.876755
# 3           CHACHAPOYAS_CHETO     3.614458  97.727273   45.017182  17.636364
# 4       CHACHAPOYAS_CHILIQUIN    10.526316  93.644860   52.526439   9.336609
# ...                       ...          ...        ...         ...        ...
# 1827         ATALAYA_RAIMONDI    16.874181  83.660898   50.963031  25.911602
# 1828         ATALAYA_TAHUANIA     9.032671  79.424978   46.224602  21.312741
# 1829            ATALAYA_YURUA     0.000000  70.950469   34.273452  18.846695
# 1830          ATALAYA_SEPAHUA    25.508721  91.419558   56.521739  32.028411
# 1831              PURUS_PURUS     0.000000  95.954357   74.906567  32.577566
#
#       trabajo_porc
# 0        35.007644
# 1         9.589041
# 2         6.638116
# 3         3.361345
# 4         4.594595
# ...            ...
# 1827     11.834255
# 1828      5.864726
# 1829     19.339623
# 1830     15.572391
# 1831     26.495726
#
# [1832 rows x 11 columns]

# %%
import geopandas as gpd

link3='https://github.com/CAP-CoyunturasCriticas/BookMaps2011/raw/refs/heads/main/distritos/DISTRITOS.shp'
dismap=gpd.read_file(link3)

# %%
dismap.head()
# Out:
#   IDDPTO DEPARTAMEN IDPROV    PROVINCIA  IDDIST                DISTRITO  \
# 0     10    HUANUCO   1009  PUERTO INCA  100902         CODO DEL POZUZO
# 1     10    HUANUCO   1009  PUERTO INCA  100904             TOURNAVISTA
# 2     25    UCAYALI   2503   PADRE ABAD  250305  ALEXANDER VON HUMBOLDT
# 3     25    UCAYALI   2503   PADRE ABAD  250302                 IRAZOLA
# 4     25    UCAYALI   2503   PADRE ABAD  250304                 NESHUYA
#
#                   CAPITAL CODCCPP  AREA FUENTE  \
# 0         CODO DEL POZUZO    0001     1   INEI
# 1             TOURNAVISTA    0001     1   INEI
# 2  ALEXANDER VON HUMBOLDT    0001     1   INEI
# 3           SAN ALEJANDRO    0001     1   INEI
# 4            MONTE ALEGRE    0001     1   INEI
#
#                                             geometry
# 0  POLYGON ((-75.31797 -9.29529, -75.3171 -9.2975...
# 1  POLYGON ((-74.64136 -8.82302, -74.64036 -8.828...
# 2  POLYGON ((-75.02253 -8.74193, -75.02267 -8.742...
# 3  POLYGON ((-75.13864 -8.56712, -75.13956 -8.569...
# 4  POLYGON ((-75.01589 -8.44637, -75.01585 -8.446...

# %%
dismap.columns
# Out:
# Index(['IDDPTO', 'DEPARTAMEN', 'IDPROV', 'PROVINCIA', 'IDDIST', 'DISTRITO',
#        'CAPITAL', 'CODCCPP', 'AREA', 'FUENTE', 'geometry'],
#       dtype='object')

# %%
dismap.drop(columns=['IDDPTO', 'IDPROV', 'IDDIST',
       'CAPITAL', 'CODCCPP', 'AREA', 'FUENTE',],inplace=True)

# %%
dismap
# Out:
#      DEPARTAMEN      PROVINCIA                DISTRITO  \
# 0       HUANUCO    PUERTO INCA         CODO DEL POZUZO
# 1       HUANUCO    PUERTO INCA             TOURNAVISTA
# 2       UCAYALI     PADRE ABAD  ALEXANDER VON HUMBOLDT
# 3       UCAYALI     PADRE ABAD                 IRAZOLA
# 4       UCAYALI     PADRE ABAD                 NESHUYA
# ...         ...            ...                     ...
# 1868    HUANUCO  LEONCIO PRADO         CASTILLO GRANDE
# 1869    HUANUCO  LEONCIO PRADO            PUEBLO NUEVO
# 1870    HUANUCO  LEONCIO PRADO   SANTO DOMINGO DE ANDA
# 1871       PUNO      SAN ROMAN              SAN MIGUEL
# 1872       LIMA         HUAURA                  HUAURA
#
#                                                geometry
# 0     POLYGON ((-75.31797 -9.29529, -75.3171 -9.2975...
# 1     POLYGON ((-74.64136 -8.82302, -74.64036 -8.828...
# 2     POLYGON ((-75.02253 -8.74193, -75.02267 -8.742...
# 3     POLYGON ((-75.13864 -8.56712, -75.13956 -8.569...
# 4     POLYGON ((-75.01589 -8.44637, -75.01585 -8.446...
# ...                                                 ...
# 1868  POLYGON ((-76.08083 -9.13017, -76.08026 -9.130...
# 1869  POLYGON ((-75.88828 -9.00906, -75.88756 -9.010...
# 1870  POLYGON ((-75.91141 -8.88593, -75.91182 -8.886...
# 1871  POLYGON ((-70.13203 -15.33382, -70.12355 -15.3...
# 1872  POLYGON ((-77.3763 -10.89734, -77.37604 -10.89...
#
# [1873 rows x 4 columns]

# %%
dismap['key']=dismap['key']=[p+'_'+d for p,d in zip(dismap.PROVINCIA,dismap.DISTRITO)]
dismap['key']=dismap['key'].apply(unidecode)
dismap
# Out:
#      DEPARTAMEN      PROVINCIA                DISTRITO  \
# 0       HUANUCO    PUERTO INCA         CODO DEL POZUZO
# 1       HUANUCO    PUERTO INCA             TOURNAVISTA
# 2       UCAYALI     PADRE ABAD  ALEXANDER VON HUMBOLDT
# 3       UCAYALI     PADRE ABAD                 IRAZOLA
# 4       UCAYALI     PADRE ABAD                 NESHUYA
# ...         ...            ...                     ...
# 1868    HUANUCO  LEONCIO PRADO         CASTILLO GRANDE
# 1869    HUANUCO  LEONCIO PRADO            PUEBLO NUEVO
# 1870    HUANUCO  LEONCIO PRADO   SANTO DOMINGO DE ANDA
# 1871       PUNO      SAN ROMAN              SAN MIGUEL
# 1872       LIMA         HUAURA                  HUAURA
#
#                                                geometry  \
# 0     POLYGON ((-75.31797 -9.29529, -75.3171 -9.2975...
# 1     POLYGON ((-74.64136 -8.82302, -74.64036 -8.828...
# 2     POLYGON ((-75.02253 -8.74193, -75.02267 -8.742...
# 3     POLYGON ((-75.13864 -8.56712, -75.13956 -8.569...
# 4     POLYGON ((-75.01589 -8.44637, -75.01585 -8.446...
# ...                                                 ...
# 1868  POLYGON ((-76.08083 -9.13017, -76.08026 -9.130...
# 1869  POLYGON ((-75.88828 -9.00906, -75.88756 -9.010...
# 1870  POLYGON ((-75.91141 -8.88593, -75.91182 -8.886...
# 1871  POLYGON ((-70.13203 -15.33382, -70.12355 -15.3...
# 1872  POLYGON ((-77.3763 -10.89734, -77.37604 -10.89...
#
#                                       key
# 0             PUERTO INCA_CODO DEL POZUZO
# 1                 PUERTO INCA_TOURNAVISTA
# 2       PADRE ABAD_ALEXANDER VON HUMBOLDT
# 3                      PADRE ABAD_IRAZOLA
# 4                      PADRE ABAD_NESHUYA
# ...                                   ...
# 1868        LEONCIO PRADO_CASTILLO GRANDE
# 1869           LEONCIO PRADO_PUEBLO NUEVO
# 1870  LEONCIO PRADO_SANTO DOMINGO DE ANDA
# 1871                 SAN ROMAN_SAN MIGUEL
# 1872                        HUAURA_HUAURA
#
# [1873 rows x 5 columns]

# %%
dismap[dismap['key'].str.contains('RAYMONDI')]
# Out:
#     DEPARTAMEN         PROVINCIA            DISTRITO  \
# 197     ANCASH  ANTONIO RAYMONDI              MIRGAS
# 199     ANCASH  ANTONIO RAYMONDI           LLAMELLIN
# 207     ANCASH  ANTONIO RAYMONDI             CHACCHO
# 241     ANCASH         BOLOGNESI    ANTONIO RAYMONDI
# 324     ANCASH  ANTONIO RAYMONDI             CHINGAS
# 580     ANCASH  ANTONIO RAYMONDI  SAN JUAN DE RONTOY
# 582     ANCASH  ANTONIO RAYMONDI                ACZO
#
#                                               geometry  \
# 197  POLYGON ((-77.10925 -9.00879, -77.10662 -9.009...
# 199  POLYGON ((-76.97515 -9.06335, -76.97395 -9.063...
# 207  POLYGON ((-77.08856 -8.97496, -77.08804 -8.975...
# 241  POLYGON ((-77.50235 -10.14658, -77.50211 -10.1...
# 324  POLYGON ((-76.94645 -9.11152, -76.94633 -9.111...
# 580  POLYGON ((-76.99577 -9.17841, -76.99574 -9.179...
# 582  POLYGON ((-76.98303 -9.14343, -76.98019 -9.144...
#
#                                      key
# 197              ANTONIO RAYMONDI_MIRGAS
# 199           ANTONIO RAYMONDI_LLAMELLIN
# 207             ANTONIO RAYMONDI_CHACCHO
# 241           BOLOGNESI_ANTONIO RAYMONDI
# 324             ANTONIO RAYMONDI_CHINGAS
# 580  ANTONIO RAYMONDI_SAN JUAN DE RONTOY
# 582                ANTONIO RAYMONDI_ACZO

# %%
dismap['key']=dismap['key'].str.replace("RAYMONDI","RAIMONDI")

# %%
dismap.merge(data2011,on='key')
# Out:
#      DEPARTAMEN    PROVINCIA_x             DISTRITO_x  \
# 0       HUANUCO    PUERTO INCA        CODO DEL POZUZO
# 1       HUANUCO    PUERTO INCA            TOURNAVISTA
# 2       UCAYALI     PADRE ABAD                IRAZOLA
# 3       UCAYALI     PADRE ABAD             PADRE ABAD
# 4       UCAYALI     PADRE ABAD               CURIMANA
# ...         ...            ...                    ...
# 1735    HUANUCO  LEONCIO PRADO   DANIEL ALOMIA ROBLES
# 1736    HUANUCO  LEONCIO PRADO              RUPA-RUPA
# 1737    HUANUCO  LEONCIO PRADO  MARIANO DAMASO BERAUN
# 1738    HUANUCO  LEONCIO PRADO                LUYANDO
# 1739       LIMA         HUAURA                 HUAURA
#
#                                                geometry  \
# 0     POLYGON ((-75.31797 -9.29529, -75.3171 -9.2975...
# 1     POLYGON ((-74.64136 -8.82302, -74.64036 -8.828...
# 2     POLYGON ((-75.13864 -8.56712, -75.13956 -8.569...
# 3     POLYGON ((-75.67827 -8.4383, -75.67668 -8.4399...
# 4     POLYGON ((-75.43663 -8.22999, -75.43651 -8.230...
# ...                                                 ...
# 1735  POLYGON ((-75.92649 -9.1626, -75.92621 -9.1626...
# 1736  POLYGON ((-76.08304 -9.07212, -76.08252 -9.072...
# 1737  POLYGON ((-75.90441 -9.28142, -75.90378 -9.281...
# 1738  POLYGON ((-76.01233 -9.15502, -76.01288 -9.155...
# 1739  POLYGON ((-77.3763 -10.89734, -77.37604 -10.89...
#
#                                       key DEPARTAMENTO    PROVINCIA_y  \
# 0             PUERTO INCA_CODO DEL POZUZO      HUANUCO    PUERTO INCA
# 1                 PUERTO INCA_TOURNAVISTA      HUANUCO    PUERTO INCA
# 2                      PADRE ABAD_IRAZOLA      UCAYALI     PADRE ABAD
# 3                   PADRE ABAD_PADRE ABAD      UCAYALI     PADRE ABAD
# 4                     PADRE ABAD_CURIMANA      UCAYALI     PADRE ABAD
# ...                                   ...          ...            ...
# 1735   LEONCIO PRADO_DANIEL ALOMIA ROBLES      HUANUCO  LEONCIO PRADO
# 1736              LEONCIO PRADO_RUPA-RUPA      HUANUCO  LEONCIO PRADO
# 1737  LEONCIO PRADO_MARIANO DAMASO BERAUN      HUANUCO  LEONCIO PRADO
# 1738                LEONCIO PRADO_LUYANDO      HUANUCO  LEONCIO PRADO
# 1739                        HUAURA_HUAURA         LIMA         HUAURA
#
#                  DISTRITO_y  Ollanta1  Ollanta2  redpub_porc   dni_porc  \
# 0           CODO DEL POZUZO  0.344043  0.366649     0.523952  86.030341
# 1               TOURNAVISTA  0.642138  0.722938     1.364024  86.765772
# 2                   IRAZOLA  0.558085  0.623604    11.468628  92.936632
# 3                PADRE ABAD  0.630665  0.700907    12.657823  94.438503
# 4                  CURIMANA  0.623040  0.690476    10.000000  92.589312
# ...                     ...       ...       ...          ...        ...
# 1735   DANIEL ALOMIA ROBLES  0.548657  0.649182     9.129129  92.558887
# 1736              RUPA-RUPA  0.342688  0.494542    48.593332  95.535840
# 1737  MARIANO DAMASO BERAUN  0.443686  0.526952     5.480683  92.827586
# 1738                LUYANDO  0.462916  0.564825     4.067948  90.626239
# 1739                 HUAURA  0.429614  0.538791    70.922499  97.472008
#
#       salud_porc   edu_porc  trabajo_porc
# 0      37.975935  17.158177      6.054280
# 1      38.836105  26.394850      4.508671
# 2      31.343205  32.271031      5.488851
# 3      36.250146  39.429799     10.199862
# 4      37.043162  33.964669      4.055767
# ...          ...        ...           ...
# 1735   44.974989  24.368378      2.206784
# 1736   31.889198  46.574260     18.109849
# 1737   40.291470  21.652224      3.362573
# 1738   38.504477  30.679975      5.295110
# 1739   33.685762  45.076475     12.842956
#
# [1740 rows x 15 columns]

# %%
dataonly=set(data2011.key)-set(dismap.key)
maponly=set(dismap.key)-set(data2011.key)
[(adata,process.extractOne(adata, maponly)) for adata in dataonly]
# Out:
# [('CHINCHEROS_ANCO-HUALLO', ('CHINCHEROS_ANCO_HUALLO', 95)),
#  ('MAYNAS_TENIENTE MANUEL CLAVERO', ('PUTUMAYO_TENIENTE MANUEL CLAVERO', 87)),
#  ('SATIPO_MAZAMARI', ('SATIPO_MAZAMARI - PANGOA', 90)),
#  ('REQUENA_SAPUENA', ('REQUENA_SAQUENA', 93)),
#  ('HUAROCHIRI_LARAOS', ('HUAROCHIRI_SAN PEDRO DE LARAOS', 72)),
#  ('YAUYOS_AYAUCA', ('YAUYOS_ALLAUCA', 89)),
#  ('NAZCA_MARCONA', ('NASCA_MARCONA', 92)),
#  ('CALLAO_CARMEN DE LA LEGUA-REYNOSO',
#   ('CALLAO_CARMEN DE LA LEGUA REYNOSO', 100)),
#  ('CHACHAPOYAS_LEYMEBAMBA', ('CHACHAPOYAS_LEIMEBAMBA', 95)),
#  ('NAZCA_NAZCA', ('NASCA_NASCA', 82)),
#  ('SECHURA_RINCONADA-LLICUAR', ('SECHURA_RINCONADA LLICUAR', 100)),
#  ('HUARAZ_PAMPAS', ('HUARAZ_PAMPAS GRANDE', 90)),
#  ('AMBO_TOMAY-KICHWA', ('AMBO_TOMAY KICHWA', 100)),
#  ('NAZCA_CHANGUILLO', ('NASCA_CHANGUILLO', 94)),
#  ('SAN MARTIN_PAPA-PLAYA', ('SAN MARTIN_PAPAPLAYA', 98)),
#  ('HUAROCHIRI_CASTA', ('HUAROCHIRI_CUENCA', 79)),
#  ('RODRIGUEZ DE MENDOZA_MILPUCC', ('RODRIGUEZ DE MENDOZA_MILPUC', 98)),
#  ('TARATA_ESTIQUE PAMPA', ('TARATA_ESTIQUE-PAMPA', 100)),
#  ('ANGARAES_HUALLAY-GRANDE', ('ANGARAES_HUAYLLAY GRANDE', 98)),
#  ('BOLOGNESI_ANTONIO RAYMONDI', ('BOLOGNESI_ANTONIO RAIMONDI', 96)),
#  ('NAZCA_EL INGENIO', ('NASCA_EL INGENIO', 94)),
#  ('AREQUIPA_SANTA RITA DE SIHUAS', ('AREQUIPA_SANTA RITA DE SIGUAS', 97)),
#  ('NAZCA_VISTA ALEGRE', ('NASCA_VISTA ALEGRE', 94)),
#  ('HUAROCHIRI_CUENCA (SAN JOSE DE LOS CHORRILLOS)', ('HUAROCHIRI_CUENCA', 90)),
#  ('CHUPACA_SAN JUAN DE YSCOS', ('CHUPACA_SAN JUAN DE ISCOS', 96)),
#  ('HUANUCO_QUISQUI', ('HUANUCO_QUISQUI (KICHKI)', 90)),
#  ('MAYNAS_PUTUMAYO', ('PUTUMAYO_PUTUMAYO', 75)),
#  ('SATIPO_PANGOA', ('SATIPO_MAZAMARI - PANGOA', 70)),
#  ('AYMARAES_HUAYLLO', ('AYMARAES_IHUAYLLO', 97))]

# %%
data2011['key']=data2011['key'].str.replace('CASTA','SAN PEDRO DE CASTA')

# %%
[(adata,process.extractOne(adata, maponly)) for adata in dataonly]
# Out:
# [('CHINCHEROS_ANCO-HUALLO', ('CHINCHEROS_ANCO_HUALLO', 95)),
#  ('MAYNAS_TENIENTE MANUEL CLAVERO', ('PUTUMAYO_TENIENTE MANUEL CLAVERO', 87)),
#  ('SATIPO_MAZAMARI', ('SATIPO_MAZAMARI - PANGOA', 90)),
#  ('REQUENA_SAPUENA', ('REQUENA_SAQUENA', 93)),
#  ('HUAROCHIRI_LARAOS', ('HUAROCHIRI_SAN PEDRO DE LARAOS', 72)),
#  ('YAUYOS_AYAUCA', ('YAUYOS_ALLAUCA', 89)),
#  ('NAZCA_MARCONA', ('NASCA_MARCONA', 92)),
#  ('CALLAO_CARMEN DE LA LEGUA-REYNOSO',
#   ('CALLAO_CARMEN DE LA LEGUA REYNOSO', 100)),
#  ('CHACHAPOYAS_LEYMEBAMBA', ('CHACHAPOYAS_LEIMEBAMBA', 95)),
#  ('NAZCA_NAZCA', ('NASCA_NASCA', 82)),
#  ('SECHURA_RINCONADA-LLICUAR', ('SECHURA_RINCONADA LLICUAR', 100)),
#  ('HUARAZ_PAMPAS', ('HUARAZ_PAMPAS GRANDE', 90)),
#  ('AMBO_TOMAY-KICHWA', ('AMBO_TOMAY KICHWA', 100)),
#  ('NAZCA_CHANGUILLO', ('NASCA_CHANGUILLO', 94)),
#  ('SAN MARTIN_PAPA-PLAYA', ('SAN MARTIN_PAPAPLAYA', 98)),
#  ('HUAROCHIRI_CASTA', ('HUAROCHIRI_CUENCA', 79)),
#  ('RODRIGUEZ DE MENDOZA_MILPUCC', ('RODRIGUEZ DE MENDOZA_MILPUC', 98)),
#  ('TARATA_ESTIQUE PAMPA', ('TARATA_ESTIQUE-PAMPA', 100)),
#  ('ANGARAES_HUALLAY-GRANDE', ('ANGARAES_HUAYLLAY GRANDE', 98)),
#  ('BOLOGNESI_ANTONIO RAYMONDI', ('BOLOGNESI_ANTONIO RAIMONDI', 96)),
#  ('NAZCA_EL INGENIO', ('NASCA_EL INGENIO', 94)),
#  ('AREQUIPA_SANTA RITA DE SIHUAS', ('AREQUIPA_SANTA RITA DE SIGUAS', 97)),
#  ('NAZCA_VISTA ALEGRE', ('NASCA_VISTA ALEGRE', 94)),
#  ('HUAROCHIRI_CUENCA (SAN JOSE DE LOS CHORRILLOS)', ('HUAROCHIRI_CUENCA', 90)),
#  ('CHUPACA_SAN JUAN DE YSCOS', ('CHUPACA_SAN JUAN DE ISCOS', 96)),
#  ('HUANUCO_QUISQUI', ('HUANUCO_QUISQUI (KICHKI)', 90)),
#  ('MAYNAS_PUTUMAYO', ('PUTUMAYO_PUTUMAYO', 75)),
#  ('SATIPO_PANGOA', ('SATIPO_MAZAMARI - PANGOA', 70)),
#  ('AYMARAES_HUAYLLO', ('AYMARAES_IHUAYLLO', 97))]

# %%
data2011[data2011['key'].str.contains('PANGOA|MAZAMARI')]
# Out:
#      DEPARTAMENTO PROVINCIA DISTRITO  Ollanta1  Ollanta2            key  \
# 1101        JUNIN    SATIPO   PANGOA  0.481736  0.528606  SATIPO_PANGOA
#
#       redpub_porc   dni_porc  salud_porc   edu_porc  trabajo_porc
# 1101    29.610149  93.621241   25.805035  33.916187      8.659134

# %%
data2011.drop(index=1099,inplace=True)

# %%
dataonly=set(data2011.key)-set(dismap.key)
maponly=set(dismap.key)-set(data2011.key)
changedat={adata:process.extractOne(adata, maponly)[0] for adata in dataonly}
changedat
# Out:
# {'CHINCHEROS_ANCO-HUALLO': 'CHINCHEROS_ANCO_HUALLO',
#  'MAYNAS_TENIENTE MANUEL CLAVERO': 'PUTUMAYO_TENIENTE MANUEL CLAVERO',
#  'REQUENA_SAPUENA': 'REQUENA_SAQUENA',
#  'HUAROCHIRI_LARAOS': 'HUAROCHIRI_SAN PEDRO DE LARAOS',
#  'PARINACOCHAS_CORONEL SAN PEDRO DE CASTANEDA': 'PARINACOCHAS_CORONEL CASTANEDA',
#  'YAUYOS_AYAUCA': 'YAUYOS_ALLAUCA',
#  'NAZCA_MARCONA': 'NASCA_MARCONA',
#  'CALLAO_CARMEN DE LA LEGUA-REYNOSO': 'CALLAO_CARMEN DE LA LEGUA REYNOSO',
#  'CHACHAPOYAS_LEYMEBAMBA': 'CHACHAPOYAS_LEIMEBAMBA',
#  'NAZCA_NAZCA': 'NASCA_NASCA',
#  'SECHURA_RINCONADA-LLICUAR': 'SECHURA_RINCONADA LLICUAR',
#  'HUARAZ_PAMPAS': 'HUARAZ_PAMPAS GRANDE',
#  'AMBO_TOMAY-KICHWA': 'AMBO_TOMAY KICHWA',
#  'NAZCA_CHANGUILLO': 'NASCA_CHANGUILLO',
#  'SAN MARTIN_PAPA-PLAYA': 'SAN MARTIN_PAPAPLAYA',
#  'RODRIGUEZ DE MENDOZA_MILPUCC': 'RODRIGUEZ DE MENDOZA_MILPUC',
#  'TARATA_ESTIQUE PAMPA': 'TARATA_ESTIQUE-PAMPA',
#  'ANGARAES_HUALLAY-GRANDE': 'ANGARAES_HUAYLLAY GRANDE',
#  'BOLOGNESI_ANTONIO RAYMONDI': 'BOLOGNESI_ANTONIO RAIMONDI',
#  'NAZCA_EL INGENIO': 'NASCA_EL INGENIO',
#  'AREQUIPA_SANTA RITA DE SIHUAS': 'AREQUIPA_SANTA RITA DE SIGUAS',
#  'NAZCA_VISTA ALEGRE': 'NASCA_VISTA ALEGRE',
#  'HUAROCHIRI_CUENCA (SAN JOSE DE LOS CHORRILLOS)': 'HUAROCHIRI_CUENCA',
#  'CHUPACA_SAN JUAN DE YSCOS': 'CHUPACA_SAN JUAN DE ISCOS',
#  'HUANUCO_QUISQUI': 'HUANUCO_QUISQUI (KICHKI)',
#  'MAYNAS_PUTUMAYO': 'PUTUMAYO_PUTUMAYO',
#  'SATIPO_PANGOA': 'SATIPO_MAZAMARI - PANGOA',
#  'AYMARAES_HUAYLLO': 'AYMARAES_IHUAYLLO'}

# %%
data2011.replace({'key':changedat}, inplace=True)

# %%
dismap#.merge(data2011,on='key')
# Out:
#      DEPARTAMEN      PROVINCIA                DISTRITO  \
# 0       HUANUCO    PUERTO INCA         CODO DEL POZUZO
# 1       HUANUCO    PUERTO INCA             TOURNAVISTA
# 2       UCAYALI     PADRE ABAD  ALEXANDER VON HUMBOLDT
# 3       UCAYALI     PADRE ABAD                 IRAZOLA
# 4       UCAYALI     PADRE ABAD                 NESHUYA
# ...         ...            ...                     ...
# 1868    HUANUCO  LEONCIO PRADO         CASTILLO GRANDE
# 1869    HUANUCO  LEONCIO PRADO            PUEBLO NUEVO
# 1870    HUANUCO  LEONCIO PRADO   SANTO DOMINGO DE ANDA
# 1871       PUNO      SAN ROMAN              SAN MIGUEL
# 1872       LIMA         HUAURA                  HUAURA
#
#                                                geometry  \
# 0     POLYGON ((-75.31797 -9.29529, -75.3171 -9.2975...
# 1     POLYGON ((-74.64136 -8.82302, -74.64036 -8.828...
# 2     POLYGON ((-75.02253 -8.74193, -75.02267 -8.742...
# 3     POLYGON ((-75.13864 -8.56712, -75.13956 -8.569...
# 4     POLYGON ((-75.01589 -8.44637, -75.01585 -8.446...
# ...                                                 ...
# 1868  POLYGON ((-76.08083 -9.13017, -76.08026 -9.130...
# 1869  POLYGON ((-75.88828 -9.00906, -75.88756 -9.010...
# 1870  POLYGON ((-75.91141 -8.88593, -75.91182 -8.886...
# 1871  POLYGON ((-70.13203 -15.33382, -70.12355 -15.3...
# 1872  POLYGON ((-77.3763 -10.89734, -77.37604 -10.89...
#
#                                       key
# 0             PUERTO INCA_CODO DEL POZUZO
# 1                 PUERTO INCA_TOURNAVISTA
# 2       PADRE ABAD_ALEXANDER VON HUMBOLDT
# 3                      PADRE ABAD_IRAZOLA
# 4                      PADRE ABAD_NESHUYA
# ...                                   ...
# 1868        LEONCIO PRADO_CASTILLO GRANDE
# 1869           LEONCIO PRADO_PUEBLO NUEVO
# 1870  LEONCIO PRADO_SANTO DOMINGO DE ANDA
# 1871                 SAN ROMAN_SAN MIGUEL
# 1872                        HUAURA_HUAURA
#
# [1873 rows x 5 columns]
